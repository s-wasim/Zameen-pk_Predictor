# %% [markdown]
# # Project Phase 1
# ### Zameen.com Price Predictor
# L191101 - Mohammad Hasaan <br>
# L192367 - Laiba Gohar <br>
# L191003 - Saad Waseem

# %%
import requests
from bs4 import BeautifulSoup as clean
import bs4
import pandas as pd
import re
import os
import threading

# %% [markdown]
# ## Getting Data
# This secton of code gives a list of all available plots present in Lahore.<br>
# We can then select specific areas to fetch data of all the plots in that area only<br>
# <b>L191011 - Mohammad Hasaan</b>

# %%
# Getting main page to extract locations
base_url = 'https://www.zameen.com'
page = requests.get('https://www.zameen.com/Plots/Lahore-1-1.html')
beautified = clean(page.text)

# %%
# Get all avaialble areas
res_set = beautified.find_all('a', attrs={'class': '_2dd261fc'})

# %% [markdown]
# ### Getting Links for Plots
# ##### Select Location
# This section of the code displays all the available plot locations for selection and getting base_url <br>
# <b>L191011 - Mohammad Hasaan</b>

# %%
locations = [(re.sub(r'\(.*\)', '', x.text), x.get('href')) for x in res_set]
for i in range(len(locations)): print(i + 1, locations[i][0], sep=' - ')
selection = None
try:
    selection = int(input('Type number of the location you want to extract plot data from'))
except ValueError:
    print('Input should be integer')
location_name = locations[selection - 1][0]
fetch_url = base_url + locations[selection - 1][1]
fetch_url = fetch_url.rsplit(sep='-', maxsplit=1)[0]
# Out:
# 1 - DHA Defence
# 2 - Raiwind Road
# 3 - Bahria Town
# 4 - Bahria Orchard
# 5 - GT Road
# 6 - Central Park Housing Scheme
# 7 - Park View City
# 8 - LDA Avenue
# 9 - New Lahore City
# 10 - DHA 11 Rahbar
# 11 - Bedian Road
# 12 - Khayaban-e-Amin
# 13 - LDA Road
# 14 - Fazaia Housing Scheme
# 15 - Al Rehman Garden
# 16 - Cantt
# 17 - Paragon City
# 18 - State Life Housing Society
# 19 - Sui Gas Housing Society
# 20 - Lahore Motorway City
# 21 - Canal Garden
# 22 - Safari Garden Housing Scheme
# 23 - IEP Engineers Town
# 24 - Park Avenue Housing Scheme
# 25 - Formanites Housing Scheme
# 26 - Johar Town
# 27 - Ferozepur Road
# 28 - Lahore - Jaranwala Road
# 29 - Grand Avenues Housing Scheme
# 30 - Chinar Bagh
# 31 - NFC 2
# 32 - Defence Road
# 33 - Jubilee Town
# 34 - Bahria Education & Medical City
# 35 - Eden
# 36 - DHA City
# 37 - Wapda Town
# 38 - OPF Housing Scheme
# 39 - Main Canal Bank Road
# 40 - Bankers Avenue Cooperative Housing Society
# 41 - Pak Arab Housing Society
# 42 - Valencia Housing Society
# 43 - EME Society
# 44 - Bahria Nasheman
# 45 - Al-Raziq Garden
# 46 - Audit & Accounts Housing Society
# 47 - Al Jalil Garden
# 48 - Multan Road
# 49 - Highcourt Society
# 50 - Jati Umra Road
# 51 - Izmir Town
# 52 - Govt Officers Cooperative Housing Society
# 53 - Jia Baga Road
# 54 - Lahore - Islamabad Motorway
# 55 - Iqbal Avenue
# 56 - Atomic Energy Society - PAEC
# 57 - Shadman Enclave
# 58 - Nasheman-e-Iqbal
# 59 - Gulberg
# 60 - BRB Canal Road
# 61 - Elite Town
# 62 - Bankers Co-operative Housing Society
# 63 - Model Town
# 64 - Punjab University Employees Society
# 65 - Tariq Gardens
# 66 - HBFC Housing Society
# 67 - Liberty Lands Housing Scheme
# 68 - Sue-e-Asal
# 69 - College Road
# 70 - Rana Town
# 71 - Thethar
# 72 - Lahore Medical Housing Society
# 73 - TIP Housing Society
# 74 - Beacon House Society
# 75 - Wagha Town
# 76 - Sukh Chayn Gardens
# 77 - Zaitoon City
# 78 - P & D Housing Society
# 79 - Rehan Garden
# 80 - Jahman
# Type number of the location you want to extract plot data from41

# %% [markdown]
# ##### Get Links
# Get the links of all plot listings available on all pages<br>
# <b>L191011 - Mohammad Hasaan</b>

# %%
page_number = 1
links = []

while True:
    # Opening selected page
    page = requests.get(fetch_url + '-' + str(page_number) + '.html')
    beautified = clean(page.text)
    page_number += 1
    
    # Listings on this page
    listings = beautified.find_all('a', class_='_7ac32433')
    if len(listings) == 0: break
    this_page = [x.get('href') for x in listings]
    links.append(this_page)
links = sum(links, [])

# %% [markdown]
# ##### Creating CSV for links
# Creating csv for all the links to reduce overhead of computation <br>
# <b>L191011 - Mohammad Hasaan</b>

# %%
links_df = pd.DataFrame(links, columns=['links'])
links_df.to_csv(location_name + '.csv')

# %% [markdown]
# ##### Combined Above Code
# <b>L191011 - Hasaan</b>

# %%
locations = [(re.sub(r'\(.*\)', '', x.text), x.get('href')) for x in res_set]

for location_name, location_url in locations[20:39]:
    fetch_url = base_url + location_url
    fetch_url = fetch_url.rsplit(sep='-', maxsplit=1)[0]
    
    # Fetch all urls in location
    page_number = 1
    links = []

    while True:
        # Opening selected page
        page = requests.get(fetch_url + '-' + str(page_number) + '.html')
        beautified = clean(page.text)
        page_number += 1

        # Listings on this page
        listings = beautified.find_all('a', class_='_7ac32433')
        if len(listings) == 0: break
        this_page = [x.get('href') for x in listings]
        links.append(this_page)
    links = sum(links, [])
    
    #Output fetched urls in csv
    links_df = pd.DataFrame(links, columns=['links'])
    links_df.to_csv(location_name + '.csv')
    
    # Print name of completed csv
    print(f'Links from {location_name} output to csv!')
# Out:
# Links from Safari Garden Housing Scheme output to csv!
# Links from Canal Garden output to csv!
# Links from IEP Engineers Town output to csv!
# Links from Park Avenue Housing Scheme output to csv!
# Links from Formanites Housing Scheme output to csv!
# Links from Chinar Bagh output to csv!
# Links from Johar Town output to csv!
# Links from Ferozepur Road output to csv!
# Links from Grand Avenues Housing Scheme output to csv!
# Links from Defence Road output to csv!
# Links from NFC 2 output to csv!
# Links from Lahore - Jaranwala Road output to csv!
# Links from Jubilee Town output to csv!
# Links from Bahria Education & Medical City output to csv!
# Links from Eden output to csv!
# Links from Wapda Town output to csv!
# Links from DHA City output to csv!
# Links from OPF Housing Scheme output to csv!
# Links from Main Canal Bank Road output to csv!

# %% [markdown]
# ### Scraping Data from Links
# Each csv file is opened in this loop and read into a list which is then appended to the base URL to fetch the actual listings page.<br>
# The target is to get <b>Ammenities</b>, <b>Installment value</b>, and <b>Plot price</b> to form a data collection that can be used for prediction<br>
# <b>L191003 - Saad Waseem</b>

# %%
import time # Import for checking execution time for each file process
from datetime import datetime

# Function to get plot details
# Class names passed as a parameter in case of future updates
def get_plot_details(page, class_='_812aa185'):
    details = page.find_all('span', attrs={'class': class_})
    return {detail.get('aria-label'): detail.text.strip() for detail in details}
def get_plot_amenities(page, class_ = '_17984a2c'):
    amenities = page.find_all('span', attrs={'class': class_})
    return ','.join([amenity.text.strip() for amenity in amenities])

# Getting details done in a function to promote parallel code.
def get_details(file):
    links = pd.read_csv('Links/' + file) # Links in files read into links
    
    # Check execution time code
    start_time_s = time.time()
    print('Time code execution began: ', datetime.now().strftime('%H:%M:%S'))
    # End of execution time code
    
    print(f'Started on Listings in file: {file}', f'File Length: {len(links)}', sep='\n', end='\n\n')
    push_list = [] # List for storing all dictionaries to be added in csv file
    # Secondary loop to iterate over all links and get data
    for _, link in links.values:
        current_page = clean(requests.get(base_url + link).text) # Get page
        push_dict = get_plot_details(current_page) # Get plot details
        push_dict['Amenities'] = get_plot_amenities(current_page) # Get Amenities
        push_list.append(push_dict) # Append dictionary to list
    
    # Check execution time code
    total_time = round(time.time() - start_time_s, 5)
    print('Time code execution ended: ', datetime.now().strftime('%H:%M:%S'))
    # End of execution time code
    
    file_name = file.split(sep='.')[0]
    pd.DataFrame.from_dict(push_list).to_csv(file_name + '_data.csv') # Output in dataframe
    print(f'Data for all links in {file} output!', f'Time taken {total_time}', sep='\n', end='\n\t-----\n')
    
# Same function above with progress percentage
def _get_details(file):
    links = pd.read_csv('Links/' + file) # Links in files read into links
    
    # Check execution time code
    start_time_s = time.time()
    print('Time code execution began: ', datetime.now().strftime('%H:%M:%S'))
    # End of execution time code
    
    print(f'Started on Listings in file: {file}', f'File Length: {links.shape[0]}', sep='\n')
    push_list = [] # List for storing all dictionaries to be added in csv file
    
    itr, t_itr = 0, links.shape[0]#Progress update
    # Secondary loop to iterate over all links and get data
    for _, link in links.values:
        current_page = clean(requests.get(base_url + link).text) # Get page
        push_dict = get_plot_details(current_page) # Get plot details
        push_dict['Amenities'] = get_plot_amenities(current_page) # Get Amenities
        push_list.append(push_dict) # Append dictionary to list
        itr += 1
        print(f'{"{:.2f}".format((itr/t_itr)*100)}%', end='\r') # Output percentage
    
    # Check execution time code
    total_time = round(time.time() - start_time_s, 5)
    print('Time code execution ended: ', datetime.now().strftime('%H:%M:%S'))
    # End of execution time code
    
    file_name = file.split(sep='.')[0]
    pd.DataFrame.from_dict(push_list).to_csv(file_name + '_data.csv') # Output in dataframe
    print(f'Data for all links in {file} output!', f'Time taken {total_time}', sep='\n', end='\n\t-----\n')

# %%
# Main loop for data collection
links_file_names = list(os.listdir('Links')) # Get all file names for csv files with links
# The below sorting is done so equal size threads execute at once to reduce wastage
links_file_names = sorted(links_file_names, key=lambda x: os.stat('Links/' + x).st_size) # Sort files by size

# Main loop iterates over all file names
# Threaded version
"""
for file_i in range(0,len(links_file_names),4):
    threads = []
    for j in range(4):
        T = threading.Thread(target=get_details, args=(links_file_names[file_i + j],), daemon=True)
        threads.append(T)
        T.start()
    for _, thread in enumerate(threads):
        thread.join()
"""
print(links_file_names)
# Non Threaded version
for file in links_file_names:
    _get_details(file)
# Out:
# ['DHA Defence.csv']
# Time code execution began:  06:13:14
# Started on Listings in file: DHA Defence.csv
# File Length: 13869
# Time code execution ended:  09:46:07
# Data for all links in DHA Defence.csv output!
# Time taken 12773.66685
# 	-----

# %% [markdown]
# ###### Threading Help
# import threading
# import time
#
# def thread_function(name):
#     print(f'Started thread {name}')
#     time.sleep(name)
#     print('Thread Done', name, flush=True)
#
# if __name__ == "__main__":
#
#     threads = list()
#     for index in range(3):
#         x = threading.Thread(target=thread_function, args=(index,) ,  daemon=True)
#         threads.append(x)
#         x.start()
#
#     for index, thread in enumerate(threads):
#         thread.join()

# %% [markdown]
# ## Cleaning Data (Data Wrangling)
# The following portion first reads all the csv files into a single dataframe and appends a new column that shows the location of the plot. The following part cleans and applies a few basic data wrangling principles to improve the visualisation of data.
# ### Reading into DataFrame
# All csv files are read into a single DataFrame<br>
# <b>L191011 - Mohammad Hasaan</b>

# %%
file_names = os.listdir('Data')
df_plots = pd.read_csv('Data/' + file_names[0]) # DataFrame created

for file in file_names[1:]:
    df_temp = pd.read_csv('Data/' + file)
    df_plots = pd.concat([df_plots, df_temp])
    del df_temp
df_plots.reset_index(drop=True, inplace=True)
del file_names
del file
df_plots
# Out:
#        Unnamed: 0              Type         Price  \
# 0               0  Residential Plot    PKR19 Lakh
# 1               1  Residential Plot    PKR45 Lakh
# 2               2  Residential Plot    PKR59 Lakh
# 3               3  Residential Plot    PKR59 Lakh
# 4               4  Residential Plot    PKR59 Lakh
# ...           ...               ...           ...
# 44026          34  Residential Plot    PKR21 Lakh
# 44027          35  Residential Plot  PKR22.5 Lakh
# 44028          36         Plot File  PKR2.25 Lakh
# 44029          37         Plot File   PKR1.5 Lakh
# 44030          38         Plot File  PKR2.25 Lakh
#
#                               Location Baths       Area   Purpose Beds  \
# 0      Al Jalil Garden, Lahore, Punjab     -    5 Marla  For Sale    -
# 1      Al Jalil Garden, Lahore, Punjab     -    5 Marla  For Sale    -
# 2      Al Jalil Garden, Lahore, Punjab     -  7.5 Marla  For Sale    -
# 3      Al Jalil Garden, Lahore, Punjab     -  7.5 Marla  For Sale    -
# 4      Al Jalil Garden, Lahore, Punjab     -  7.5 Marla  For Sale    -
# ...                                ...   ...        ...       ...  ...
# 44026     Zaitoon City, Lahore, Punjab     -    3 Marla  For Sale    -
# 44027     Zaitoon City, Lahore, Punjab     -  4.4 Marla  For Sale    -
# 44028     Zaitoon City, Lahore, Punjab     -    3 Marla  For Sale    -
# 44029     Zaitoon City, Lahore, Punjab     -    5 Marla  For Sale    -
# 44030     Zaitoon City, Lahore, Punjab     -    5 Marla  For Sale    -
#
#       Creation date                                          Amenities  \
# 0         1 day ago  Possesion,File,Balloted,Sewerage,Electricity,W...
# 1         1 day ago  Possesion,File,Balloted,Sewerage,Electricity,W...
# 2        4 days ago                                                NaN
# 3        4 days ago                                                NaN
# 4        4 days ago                                                NaN
# ...             ...                                                ...
# 44026  5 months ago  Possesion,Corner,Park Facing,Disputed,File,Bal...
# 44027  5 months ago                                                NaN
# 44028  6 months ago                                                NaN
# 44029  6 months ago                                                NaN
# 44030  7 months ago                                                NaN
#
#             advance Monthly installment Remaining installments
# 0               NaN                 NaN                    NaN
# 1               NaN                 NaN                    NaN
# 2               NaN                 NaN                    NaN
# 3               NaN                 NaN                    NaN
# 4               NaN                 NaN                    NaN
# ...             ...                 ...                    ...
# 44026  PKR4.75 Lakh      PKR17 Thousand              33 Months
# 44027           NaN                 NaN                    NaN
# 44028           NaN                 NaN                    NaN
# 44029           NaN                 NaN                    NaN
# 44030           NaN                 NaN                    NaN
#
# [44031 rows x 13 columns]

# %% [markdown]
# ### Cleaning Data
# Unnecessary columns are dropped<br>
# <b>L191011 - Mohammad Hasaan</b>

# %%
df_plots.drop(columns=['Unnamed: 0', 'Beds', 'Baths', 'Purpose'], axis=1, inplace=True)
drop_list = list(df_plots[df_plots['Price'].isnull()].index)
df_plots.drop(drop_list, inplace=True)
del drop_list
df_plots
# Out:
#                    Type         Price                         Location  \
# 0      Residential Plot    PKR19 Lakh  Al Jalil Garden, Lahore, Punjab
# 1      Residential Plot    PKR45 Lakh  Al Jalil Garden, Lahore, Punjab
# 2      Residential Plot    PKR59 Lakh  Al Jalil Garden, Lahore, Punjab
# 3      Residential Plot    PKR59 Lakh  Al Jalil Garden, Lahore, Punjab
# 4      Residential Plot    PKR59 Lakh  Al Jalil Garden, Lahore, Punjab
# ...                 ...           ...                              ...
# 44026  Residential Plot    PKR21 Lakh     Zaitoon City, Lahore, Punjab
# 44027  Residential Plot  PKR22.5 Lakh     Zaitoon City, Lahore, Punjab
# 44028         Plot File  PKR2.25 Lakh     Zaitoon City, Lahore, Punjab
# 44029         Plot File   PKR1.5 Lakh     Zaitoon City, Lahore, Punjab
# 44030         Plot File  PKR2.25 Lakh     Zaitoon City, Lahore, Punjab
#
#             Area Creation date  \
# 0        5 Marla     1 day ago
# 1        5 Marla     1 day ago
# 2      7.5 Marla    4 days ago
# 3      7.5 Marla    4 days ago
# 4      7.5 Marla    4 days ago
# ...          ...           ...
# 44026    3 Marla  5 months ago
# 44027  4.4 Marla  5 months ago
# 44028    3 Marla  6 months ago
# 44029    5 Marla  6 months ago
# 44030    5 Marla  7 months ago
#
#                                                Amenities       advance  \
# 0      Possesion,File,Balloted,Sewerage,Electricity,W...           NaN
# 1      Possesion,File,Balloted,Sewerage,Electricity,W...           NaN
# 2                                                    NaN           NaN
# 3                                                    NaN           NaN
# 4                                                    NaN           NaN
# ...                                                  ...           ...
# 44026  Possesion,Corner,Park Facing,Disputed,File,Bal...  PKR4.75 Lakh
# 44027                                                NaN           NaN
# 44028                                                NaN           NaN
# 44029                                                NaN           NaN
# 44030                                                NaN           NaN
#
#       Monthly installment Remaining installments
# 0                     NaN                    NaN
# 1                     NaN                    NaN
# 2                     NaN                    NaN
# 3                     NaN                    NaN
# 4                     NaN                    NaN
# ...                   ...                    ...
# 44026      PKR17 Thousand              33 Months
# 44027                 NaN                    NaN
# 44028                 NaN                    NaN
# 44029                 NaN                    NaN
# 44030                 NaN                    NaN
#
# [43320 rows x 9 columns]

# %% [markdown]
# Row-wise operations done for each colum<br>
# Standardising price, area, and sorting Amenities for Categorical encoding <br>
# <b>L192367 - Laiba Gohar & L191003 - Saad Waseem</b>

# %%
for i in range(df_plots.shape[0]):
    # Sort Amenities so they can be categorically encoded
    df_plots['Amenities'].iloc[i] = ','.join(sorted(str(df_plots['Amenities'].iloc[i]).split(sep=',')))
    # Since location is in lahore, punjab we remove that part of the location
    df_plots['Location'].iloc[i] = df_plots['Location'].iloc[i].split(sep=',')[0]
    
    # Set prices in standard 1rs. unit
    if re.search(r'PKR(\d*\.*\d*) (.*)', df_plots['Price'].iloc[i]).group(2) == 'Lakh':
        df_plots['Price'].iloc[i] = int(float(re.search(r'PKR(\d*\.*\d*) (.*)', df_plots['Price'].iloc[i]).group(1)) * 100000)
    else:
        df_plots['Price'].iloc[i] = int(float(re.search(r'PKR(\d*\.*\d*) (.*)', df_plots['Price'].iloc[i]).group(1)) * 10000000)
    
    # Set plot in standard marlas unit
    if re.search(r'(\d*\.*\d*) (.*)', df_plots['Area'].iloc[i]).group(2) == 'Marla':
        df_plots['Area'].iloc[i] = float(re.search(r'(\d*\.*\d*) (.*)', df_plots['Area'].iloc[i]).group(1))
    else:
        df_plots['Area'].iloc[i] = float(re.search(r'(\d*\.*\d*) (.*)', df_plots['Area'].iloc[i]).group(1)) * 20

# Convert both the data types to numeric
df_plots['Area'] = pd.to_numeric(df_plots['Area'])
df_plots['Price'] = pd.to_numeric(df_plots['Price'])

# %% [markdown]
# Calculating installments value<br>
# <b>L192367 - Laiba Gohar & L191003 - Saad Waseem</b>

# %%
def get_value(number, suffix):
    adv_val = 0
    match suffix:
        case 'Thousand':
            adv_val = int(float(number) * 1000)
        case 'Lakh':
            adv_val = int(float(number) * 100000)
        case 'Crore':
            adv_val = int(float(number) * 10000000)
    return int(adv_val)

# %%
df_series = df_plots[~df_plots['advance'].isnull()][['advance', 'Monthly installment', 'Remaining installments']]
adv_val, months, rem_install, _list = 0, 0, 0, []
append_list = []

for i in range(df_series.shape[0]):
    # Getting advance Value
    _list = re.search(r'PKR(\d+\.*\d*)(.*)', df_series['advance'].iloc[i]).groups()
    adv_val = get_value(float(_list[0]), _list[1].strip())
    
    # Getting monthly installment
    _list = re.search(r'PKR(\d+\.*\d*)(.*)', df_series['Monthly installment'].iloc[i]).groups()
    months = get_value(float(_list[0]), _list[1].strip())
    
    # Remaining installments
    rem_install = int(re.search(r'(\d+).*', df_series['Remaining installments'].iloc[i]).group(1))
    append_list.append((months * rem_install) + adv_val)
    
df_series['Installment value'] = append_list
df_series.drop(columns=['advance', 'Monthly installment', 'Remaining installments'], axis=1, inplace=True)

# Merging both the DataFrames on index
df_plots.drop(columns=['advance', 'Monthly installment', 'Remaining installments'], axis=1 ,inplace=True)
df_plots = df_plots.join(other=df_series).copy()

del append_list, adv_val, months, rem_install, _list, df_series

# %% [markdown]
# Categorically encoded Amenities<br>
# <b>L192367 - Laiba Gohar & L191003 - Saad Waseem</b>

# %%
from pandas.api.types import CategoricalDtype

categories = CategoricalDtype(list(df_plots['Amenities'].unique()), ordered=True)
df_plots['Amenities'] = df_plots['Amenities'].astype(categories).cat.codes

# %% [markdown]
# Checking data

# %%
print(df_plots.describe())
df_plots
# Out:
#               Price          Area     Amenities  Installment value
# count  4.332000e+04  43320.000000  43320.000000       8.950000e+02
# mean   2.326870e+07     22.419965    173.555609       4.359425e+06
# std    4.433047e+07    241.818415    353.333889       8.229414e+06
# min    1.000000e+05      0.000000      0.000000       0.000000e+00
# 25%    5.500000e+06      5.000000      1.000000       1.024000e+06
# 50%    1.120000e+07     10.000000      1.000000       1.965000e+06
# 75%    2.600000e+07     20.000000    125.000000       4.378000e+06
# max    9.900000e+08  19200.000000   1951.000000       1.000000e+08
#                    Type    Price         Location  Area Creation date  \
# 0      Residential Plot  1900000  Al Jalil Garden   5.0     1 day ago
# 1      Residential Plot  4500000  Al Jalil Garden   5.0     1 day ago
# 2      Residential Plot  5900000  Al Jalil Garden   7.5    4 days ago
# 3      Residential Plot  5900000  Al Jalil Garden   7.5    4 days ago
# 4      Residential Plot  5900000  Al Jalil Garden   7.5    4 days ago
# ...                 ...      ...              ...   ...           ...
# 44026  Residential Plot  2100000     Zaitoon City   3.0  5 months ago
# 44027  Residential Plot  2250000     Zaitoon City   4.4  5 months ago
# 44028         Plot File   225000     Zaitoon City   3.0  6 months ago
# 44029         Plot File   150000     Zaitoon City   5.0  6 months ago
# 44030         Plot File   225000     Zaitoon City   5.0  7 months ago
#
#        Amenities  Installment value
# 0              0                NaN
# 1              0                NaN
# 2              1                NaN
# 3              1                NaN
# 4              1                NaN
# ...          ...                ...
# 44026       1686          1036000.0
# 44027          1                NaN
# 44028          1                NaN
# 44029          1                NaN
# 44030          1                NaN
#
# [43320 rows x 7 columns]

# %% [markdown]
# ### Standardising Price, Area and Installment value
# <b>L191011 - Mohammad Hasaan</b>

# %%
# Normalising values
mean_list = df_plots[['Price', 'Area', 'Installment value']].mean()
stdd_list = df_plots[['Price', 'Area', 'Installment value']].std()
df_standard = df_plots[['Price', 'Area', 'Installment value']]
df_standard = (df_standard - mean_list) / stdd_list

# Standardising normalised values
max_list = df_standard.max()
den_list = max_list - df_standard.min()
df_standard = (max_list - df_standard) / den_list

df_standard.describe()
# Out:
#               Price          Area  Installment value
# count  43320.000000  43320.000000         895.000000
# mean       0.976595      0.998832           0.956406
# std        0.044783      0.012595           0.082294
# min        0.000000      0.000000           0.000000
# 25%        0.973836      0.998958           0.956220
# 50%        0.988787      0.999479           0.980350
# 75%        0.994545      0.999740           0.989760
# max        1.000000      1.000000           1.000000

# %% [markdown]
# ### Outputting Cleaned Data
# <b>L191011 - Mohammad Hasaan</b>

# %%
df_standard.to_csv('Data/Cleaned/Standardised.csv')
df_plots.to_csv('Data/Cleaned/Cleaned_Data.csv')

# %% [markdown]
# ## Plotting Data
# Testing plot. Not part of the deliverable

# %%
df_standard.plot()
# Out:
# <Axes: >
